# %% [markdown]
# # テスト 正弦波指令

# %% [markdown]
# # 1. NumPy sin
#
# numpy.sin<br>
# https://numpy.org/devdocs/reference/generated/numpy.sin.html

# %%
import numpy as np
print(f"{np.pi=}")
print(f"{np.sin(np.pi/2)=}")

# %% [markdown]
# # 2. 正弦波コントローラ

# %%
#【正弦波コントローラ】モーションフロー作成
import pprint
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.load_discrete_time()
flow.load_motion_profile()  # loads default profile

# 正弦波コントローラ
sinusoidal_ctrl_index = 4
flow.load_controller(filepath="tkmotion/ctrl/default_controller_config.json", ctrl_index=sinusoidal_ctrl_index)
pprint.pprint(type(flow.controller))
pprint.pprint(flow.controller.get_config())

# 質量・ダンパ・ばねモデル
plant_index=1
phyobj_index=0
flow.load_plant(filepath="tkmotion/plant/default_plant_config.json", plant_index=plant_index, phyobj_index=phyobj_index)

# %%
#【正弦波コントローラ】MotionFlow実行
mtnflow_df = flow.execute()
mtnflow_df

# %%
# 【正弦波コントローラ】指令推力の確認
import plotly.express as px
fig = px.line(mtnflow_df, x="time_s", y=["force_N"], title="Force")
fig.update_layout(
    xaxis=dict(title="time [s]"),
    yaxis=dict(title="force [N]"))
fig.show()

# %%
#【正弦波コントローラ】MotionFlow実行結果の可視化
import plotly.express as px
fig = px.line(
    mtnflow_df,
    x="time_s",
    y=["obj_velocity_m_s", "obj_position_m"],
    title="Motion Profile Execution Result")
fig.update_layout(
    yaxis2=dict(
        title="Position (m)",  # 第2Y軸のタイトル
        overlaying="y",        # 第1Y軸の上に重ねる
        side="right",          # 右側に表示
        showgrid=False         # オプション: グリッド線を非表示
    ),
)
for trace in fig.data:
    # 第2Y軸のトレース更新 / Update 2nd Y-axis trace
    if trace.name == "obj_position_m":
        trace.update(yaxis="y2")
        break
fig.update_yaxes(title_text="Velocity (m/s)", row=1, col=1)
fig.update_xaxes(title_text="Time (s)", row=1, col=1)
fig.show()

# %% [markdown]
# # 3. 正弦波プロファイル

# %%
#【正弦波プロファイル】モーションフロー作成
import pprint
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.load_discrete_time()

# 正弦波プロファイル
sinusoidal_prof_index = 6
flow.load_motion_profile(filepath="tkmotion/prof/default_motion_prof_config.json", prof_index=sinusoidal_prof_index)
pprint.pprint(type(flow.mprof))
pprint.pprint(flow.mprof.get_config())

# PIDコントローラ
pid_ctrl_index = 1
flow.load_controller(filepath="tkmotion/ctrl/default_controller_config.json", ctrl_index=pid_ctrl_index)
pprint.pprint(type(flow.controller))

# 質量・ダンパ・ばねモデル
plant_index=1
phyobj_index=0
flow.load_plant(filepath="tkmotion/plant/default_plant_config.json", plant_index=plant_index, phyobj_index=phyobj_index)
pprint.pprint(type(flow.plant.physical_obj))

# %%
#【正弦波プロファイル】MotionFlow実行
mtnflow_df = flow.execute()
mtnflow_df

# %%
#【正弦波プロファイル】指令値の可視化
import plotly.express as px
fig = px.line(
    mtnflow_df,
    x="time_s",
    y=["cmd_velocity_m_s", "cmd_position_m"],
    title="Motion Profile Command")
fig.update_layout(
    yaxis2=dict(
        title="Position (m)",  # 第2Y軸のタイトル
        overlaying="y",        # 第1Y軸の上に重ねる
        side="right",          # 右側に表示
        showgrid=False         # オプション: グリッド線を非表示
    ),
)
for trace in fig.data:
    # 第2Y軸のトレース更新 / Update 2nd Y-axis trace
    if trace.name == "cmd_position_m":
        trace.update(yaxis="y2")
        break
fig.update_yaxes(title_text="Velocity (m/s)", row=1, col=1)
fig.update_xaxes(title_text="Time (s)", row=1, col=1)
fig.show()

# %%
#【正弦波プロファイル】MotionFlow実行結果の可視化
import plotly.express as px
fig = px.line(
    mtnflow_df,
    x="time_s",
    y=["obj_velocity_m_s", "obj_position_m"],
    title="Motion Profile Execution Result")
fig.update_layout(
    yaxis2=dict(
        title="Position (m)",  # 第2Y軸のタイトル
        overlaying="y",        # 第1Y軸の上に重ねる
        side="right",          # 右側に表示
        showgrid=False         # オプション: グリッド線を非表示
    ),
)
for trace in fig.data:
    # 第2Y軸のトレース更新 / Update 2nd Y-axis trace
    if trace.name == "obj_position_m":
        trace.update(yaxis="y2")
        break
fig.update_yaxes(title_text="Velocity (m/s)", row=1, col=1)
fig.update_xaxes(title_text="Time (s)", row=1, col=1)
fig.show()

# %% [markdown]
# # 4. サインスイープコントローラ

# %%
#【サインスイープコントローラ】モーションフロー作成
import pprint
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.load_discrete_time()
flow.load_motion_profile()  # loads default profile

# サインスイープコントローラ
sinsweep_ctrl_index = 5
flow.load_controller(filepath="tkmotion/ctrl/default_controller_config.json", ctrl_index=sinsweep_ctrl_index)
pprint.pprint(type(flow.controller))
pprint.pprint(flow.controller.get_config())

# 質量・ダンパ・ばねモデル
plant_index=1
phyobj_index=0
flow.load_plant(filepath="tkmotion/plant/default_plant_config.json", plant_index=plant_index, phyobj_index=phyobj_index)

# %%
#【サインスイープコントローラ】MotionFlow実行
mtnflow_df = flow.execute()
mtnflow_df

# %%
# 【サインスイープコントローラ】指令推力の確認
import plotly.express as px
fig = px.line(mtnflow_df, x="time_s", y=["force_N"], title="Force")
fig.update_layout(
    xaxis=dict(title="time [s]"),
    yaxis=dict(title="force [N]"))
fig.show()

# %%
#【サインスイープコントローラ】MotionFlow実行結果の可視化
import plotly.express as px
fig = px.line(
    mtnflow_df,
    x="time_s",
    y=["obj_velocity_m_s", "obj_position_m"],
    title="Motion Profile Execution Result")
fig.update_layout(
    yaxis2=dict(
        title="Position (m)",  # 第2Y軸のタイトル
        overlaying="y",        # 第1Y軸の上に重ねる
        side="right",          # 右側に表示
        showgrid=False         # オプション: グリッド線を非表示
    ),
)
for trace in fig.data:
    # 第2Y軸のトレース更新 / Update 2nd Y-axis trace
    if trace.name == "obj_position_m":
        trace.update(yaxis="y2")
        break
fig.update_yaxes(title_text="Velocity (m/s)", row=1, col=1)
fig.update_xaxes(title_text="Time (s)", row=1, col=1)
fig.show()

# %% [markdown]
# # 5. 周波数応答関数
# $$
# 周波数応答関数 H(f) = \frac{出力波形の周波数スペクトル B(f)}{入力波形の周波数スペクトル A(f)}
# $$
#
# ※ $A(f)$、$B(f)$、$H(f)$ の値は複素数
#
# 引用：小野測器 FFT解析に関する 基礎用語集<br>
# https://www.onosokki.co.jp/HP-WK/c_support/tech_term/cf_fft/cf3_3_2.htm

# %% [markdown]
# ## 5.1 時系列データの要件
#
# ### 5.1.1 分析対象のスイープ周波数
# 1. スイープ開始周波数 $f_{start}$ = 0.1 [Hz]
# 2. スイープ終了周波数 $f_{end}$ = 10 [Hz]
# 3. 周波数分解能 $\Delta f_{req}$ = 0.1 [Hz]
#
# ### 5.1.2 時系列データの要件
# 1. 周波数分解能 --> 最低限必要な時間（最小（最遅）周波数の波 1個分）
# $$
# T_{req-min} = \frac{1}{\Delta f_{req}} = \frac{1}{0.1} = 10 [\mathrm{s}]
# $$
#
# 2. 最大分析周波数 --> 最低限必要なサンプリング周波数（最大（最速）周波数の2.56倍（※1））、時間刻み
# $$
# f_{req-min} = f_{end} \times 2.56 = 10 \times 2.56 = 25.6 [\mathrm{Hz}]
# $$
# $$
# \Delta t_{req-max} = \frac{1}{f_{req-min}} = \frac{1}{25.6} = 0.039625 [\mathrm{s}]
# $$
# 3. 最低限必要なデータ点数
# $$
# N_{req-min} = T_{req-min} \times f_{req-min} = 10 \times 25.6 = 256 [個]
# $$
# 4. 最低限必要なデータ点数（FFT要件 2のn乗）
# $$
# N_{fft-min} = N_{req}を2のn乗に切り上げ = 切り上げ(256) = 2^8 (そのまま)
# $$
#
# (※1) 2.56: エイリアシングの影響を低減するために、実際に使われる倍率<br>
# 引用：小野測器　周波数レンジとサンプリング周波数との関係は？<br>
# https://www.onosokki.co.jp/HP-WK/c_support/faq/fft_common/fft_analys_1.htm
#
# (※2) Note: 周波数 f [Hz]: 単位時間当たりのデータ個数 n [1/s]

# %% [markdown]
# ### 5.1.3 時系列データの要件（シミュレーション精度向上）
#
# 滑らかな波形を得るために、以下の条件を満たすように、サンプリング周波数を大きくする。
# 1. 最低限必要なサンプリング周波数の10倍以上
# 2. データ点数 2のn乗
#
# $$
# f_{req} = f_{end} \times 40.96 = 10 \times 40.96 = 409.6 [\mathrm{Hz}]
# $$
# $$
# \Delta t_{req} = \frac{1}{f_{req}} = \frac{1}{409.6} = 0.00244140625 [\mathrm{s}]
# $$
# $$
# N_{req} = T_{req-min} \times f_{req} = 10 \times 409.6 = 4096 [個]
# $$

# %%
print(f"{1/25.6=}")
print(f"{1/409.6=}")

# %%
print(f"{2**8=}")
print(f"{2**9=}")
print(f"{2**10=}")
print(f"{2**11=}")
print(f"{2**12=}")

# %% [markdown]
# ## 5.2 入力と出力の周波数スペクトル

# %% [markdown]
# ### 5.2.1 モーションフロー作成

# %%
#【FFT】モーションフロー作成
import pprint
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.load_discrete_time()
flow.discrete_time.dt = 1 / 409.6  # 時系列データ要件 Δt [s] (シミュレーション精度向上)
flow.discrete_time.duration = 10.0  # 時系列データ要件 T [s]
print(f"{flow.discrete_time.dt=}s")
print(f"{flow.discrete_time.duration=}s")
flow.load_motion_profile()

# サインスイープコントローラ
sinsweep_ctrl_index = 5
flow.load_controller(filepath="tkmotion/ctrl/default_controller_config.json", ctrl_index=sinsweep_ctrl_index)
flow.controller.f_start = 0.1  # 開始周波数 [Hz]
flow.controller.f_end = 10.0   # 終了周波数 [Hz]
flow.controller.T = flow.discrete_time.duration
print(f"{flow.controller.f_start=}Hz")
print(f"{flow.controller.f_end=}Hz")
print(f"{flow.controller.T=}s")

# 質量・ダンパ・ばねモデル
plant_index=1
phyobj_index=0
flow.load_plant(filepath="tkmotion/plant/default_plant_config.json", plant_index=plant_index, phyobj_index=phyobj_index)

# %% [markdown]
# ### 5.2.2 プラント（物理オブジェクト）の特性値を確認
#
# 固有振動数 ≒ 1Hz。周波数応答関数のゲイン値は、この1Hz付近でピークとなることが期待される。

# %%
wn_Hz, cc, zeta, wd_Hz = flow.plant.physical_obj.calc_char_values()
print(f"固有振動数{wn_Hz=}[Hz]")
print(f"臨界減衰率{cc=}")
print(f"減衰比{zeta=}")
print(f"減衰系の固有振動数{wd_Hz=}[Hz]")

# %% [markdown]
# ### 5.2.3 モーションフロー実行

# %%
#【FFT】MotionFlow実行
mtnflow_df = flow.execute()
mtnflow_df

# %%
# 【FFT】データ点数の確認（0を含むため、4096 + 1点)
len(mtnflow_df["time_s"])

# %%
#【FFT】FFT用の時間配列（最後の点を除く）
mtnflow_df["time_s"][:-1]

# %% [markdown]
# ### 5.2.4 指令推力波形の確認
#
# (OK) 滑らかな0.1 ~ 10Hzの波形を生成できている。

# %%
# 【FFT】指令推力の確認
import plotly.express as px
fig = px.line(mtnflow_df, x="time_s", y=["force_N"], title="Force")
fig.update_layout(
    xaxis=dict(title="time [s]"),
    yaxis=dict(title="force [N]"))
fig.show()

# %% [markdown]
# ### 5.2.5 物理オブジェクトの応答波形の確認
#
# (OK) 1Hz付近の振幅が最大となっている。（セクション「5.2.2 プラント（物理オブジェクト）の特性値を確認」の期待値と一致）

# %%
#【FFT】MotionFlow実行結果の可視化
import plotly.express as px
fig = px.line(
    mtnflow_df,
    x="time_s",
    y=["obj_velocity_m_s", "obj_position_m"],
    title="Motion Profile Execution Result")
fig.update_layout(
    yaxis2=dict(
        title="Position (m)",  # 第2Y軸のタイトル
        overlaying="y",        # 第1Y軸の上に重ねる
        side="right",          # 右側に表示
        showgrid=False         # オプション: グリッド線を非表示
    ),
)
for trace in fig.data:
    # 第2Y軸のトレース更新 / Update 2nd Y-axis trace
    if trace.name == "obj_position_m":
        trace.update(yaxis="y2")
        break
fig.update_yaxes(title_text="Velocity (m/s)", row=1, col=1)
fig.update_xaxes(title_text="Time (s)", row=1, col=1)
fig.show()

# %% [markdown]
# ### 5.2.6 入力と出力の周波数スペクトル
#
# (OK) 推力の周波数スペクトルは、スイープ範囲（0.1 ～ 10Hz）で非ゼロ値。<br>
# (OK) 物理オブジェクト位置の周波数スペクトルは、1Hz付近で最大となっている。（セクション「5.2.2 プラント（物理オブジェクト）の特性値を確認」の期待値と一致）

# %%
#【FFT】FFT分析
from scipy.fft import fft, fftfreq
import numpy as np

# Number of sample points
N = len(mtnflow_df["time_s"][:-1])  # 最後の点を除き、4096点(2^12)にする
print(f"{N=}")

# sample spacing
d = flow.discrete_time.dt  # [s]
print(f"{d=}")

# spectrum (推力)
yf_force = fft(mtnflow_df["force_N"][:-1])
yf_force_norm = np.abs(yf_force) / (N)  # 両側スペクトル正規化 (Nで除算)
print(f"{yf_force.shape=}")

# spectrum (物理オブジェクト位置)
yf_obj_pos = fft(mtnflow_df["obj_position_m"][:-1])
yf_obj_pos_norm = np.abs(yf_obj_pos) / (N)
print(f"{yf_obj_pos.shape=}")

# sample frequencies (n: window length, d: sample spacing)
# f = [0, 1, ...,   n/2-1,     -n/2, ..., -1] / (d*n)   if n is even
# f = [0, 1, ..., (n-1)/2, -(n-1)/2, ..., -1] / (d*n)   if n is odd
xf = fftfreq(n=N, d=d)

import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_force_norm, name='周波数スペクトル（推力）'))
fig.update_layout(showlegend=True, title='周波数スペクトル (推力)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_obj_pos_norm, name='周波数スペクトル (物理オブジェクト位置)'))
fig.update_layout(showlegend=True, title='周波数スペクトル (物理オブジェクト位置)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

# %% [markdown]
# ## 5.3 周波数応答関数
#
# 周波数応答関数を求める式（再掲）
# $$
# 周波数応答関数 H(f) = \frac{出力波形の周波数スペクトル B(f)}{入力波形の周波数スペクトル A(f)}
# $$
#
# ※ $A(f)$、$B(f)$、$H(f)$ の値は複素数

# %% [markdown]
# ### 5.3.1 全周波数範囲
#
# Pythonの数値計算ライブラリで計算値の全容を知るために、まず、あえて、計算された全周波数範囲をプロットする。
#
# (OK) ゲインは1Hzで最大。<br>
# (OK) 正の周波数範囲において、位相は遅れていく。

# %%
f_response = yf_obj_pos / yf_force
f_response_norm = np.abs(f_response) / (N)
f_response_angle = np.angle(f_response)
f_response_angle_deg = np.degrees(f_response_angle)

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_norm, name='周波数応答関数'))
fig.update_layout(showlegend=True, title='周波数応答関数（ゲイン）', xaxis_title='周波数 [Hz]', yaxis_title='振幅')

fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_angle_deg, name='周波数応答関数（位相）'))
fig.update_layout(showlegend=True, title='周波数応答関数（位相）', xaxis_title='周波数 [Hz]', yaxis_title='位相 [deg]')
fig.show()

# %% [markdown]
# ### 5.3.2 スイープ周波数の範囲
#
# プロット範囲を、物理的に意味を持つ、スイープ周波数の範囲に絞る。

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_norm, name='周波数応答関数'))
fig.update_layout(showlegend=True, title='周波数応答関数（ゲイン）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_angle_deg, name='周波数応答関数（位相）'))
fig.update_layout(showlegend=True, title='周波数応答関数（位相）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='位相 [deg]')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()

# %% [markdown]
# ### 5.3.3 rfft（実数範囲のFFT）を使う

# %%
#【FFT】FFT分析
from scipy.fft import rfft, rfftfreq
import numpy as np

# Number of sample points
N = len(mtnflow_df["time_s"][:-1])  # 最後の点を除き、4096点(2^12)にする
print(f"{N=}")

# sample spacing
d = flow.discrete_time.dt  # [s]
print(f"{d=}")

# spectrum (推力)
yf_force = rfft(mtnflow_df["force_N"][:-1])
yf_force_norm = np.abs(yf_force) / (N)  # 両側スペクトル正規化 (Nで除算)
print(f"{yf_force.shape=}")

# spectrum (物理オブジェクト位置)
yf_obj_pos = rfft(mtnflow_df["obj_position_m"][:-1])
yf_obj_pos_norm = np.abs(yf_obj_pos) / (N)
print(f"{yf_obj_pos.shape=}")

# sample frequencies (n: window length, d: sample spacing)
# f = [0, 1, ...,   n/2-1,     -n/2, ..., -1] / (d*n)   if n is even
# f = [0, 1, ..., (n-1)/2, -(n-1)/2, ..., -1] / (d*n)   if n is odd
xf = rfftfreq(n=N, d=d)

import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_force_norm, name='周波数スペクトル（推力）'))
fig.update_layout(showlegend=True, title='周波数スペクトル (推力)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_obj_pos_norm, name='周波数スペクトル (物理オブジェクト位置)'))
fig.update_layout(showlegend=True, title='周波数スペクトル (物理オブジェクト位置)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

# %%
f_response = yf_obj_pos / yf_force
f_response_norm = np.abs(f_response) / (N)
f_response_angle = np.angle(f_response)
f_response_angle_deg = np.degrees(f_response_angle)

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_norm, name='周波数応答関数'))
fig.update_layout(showlegend=True, title='周波数応答関数（ゲイン）', xaxis_title='周波数 [Hz]', yaxis_title='振幅')

fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_angle_deg, name='周波数応答関数（位相）'))
fig.update_layout(showlegend=True, title='周波数応答関数（位相）', xaxis_title='周波数 [Hz]', yaxis_title='位相 [deg]')
fig.show()

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_norm, name='周波数応答関数'))
fig.update_layout(showlegend=True, title='周波数応答関数（ゲイン）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_angle_deg, name='周波数応答関数（位相）'))
fig.update_layout(showlegend=True, title='周波数応答関数（位相）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='位相 [deg]')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()

# %% [markdown]
# ## 5.3.4 速度の応答

# %%
#【FFT】FFT分析
from scipy.fft import rfft, rfftfreq
import numpy as np

# Number of sample points
N = len(mtnflow_df["time_s"][:-1])  # 最後の点を除き、4096点(2^12)にする
print(f"{N=}")

# sample spacing
d = flow.discrete_time.dt  # [s]
print(f"{d=}")

# spectrum (推力)
yf_force = rfft(mtnflow_df["force_N"][:-1])
yf_force_norm = np.abs(yf_force) / (N)  # 両側スペクトル正規化 (Nで除算)
print(f"{yf_force.shape=}")

# spectrum (物理オブジェクト速度)
yf_obj_pos = rfft(mtnflow_df["obj_velocity_m_s"][:-1])
yf_obj_pos_norm = np.abs(yf_obj_pos) / (N)
print(f"{yf_obj_pos.shape=}")

# sample frequencies (n: window length, d: sample spacing)
# f = [0, 1, ...,   n/2-1,     -n/2, ..., -1] / (d*n)   if n is even
# f = [0, 1, ..., (n-1)/2, -(n-1)/2, ..., -1] / (d*n)   if n is odd
xf = rfftfreq(n=N, d=d)

import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_force_norm, name='周波数スペクトル（推力）'))
fig.update_layout(showlegend=True, title='周波数スペクトル (推力)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=yf_obj_pos_norm, name='周波数スペクトル (物理オブジェクト速度)'))
fig.update_layout(showlegend=True, title='周波数スペクトル (物理オブジェクト速度)', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[-15, 15])  # X軸を-15～15Hzに制限
fig.show()

# %%
f_response = yf_obj_pos / yf_force
f_response_norm = np.abs(f_response) / (N)
f_response_angle = np.angle(f_response)
f_response_angle_deg = np.degrees(f_response_angle)

import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_norm, name='周波数応答関数'))
fig.update_layout(showlegend=True, title='周波数応答関数（ゲイン）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='振幅')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()

fig = go.Figure()
fig.add_trace(go.Scatter(x=xf, y=f_response_angle_deg, name='周波数応答関数（位相）'))
fig.update_layout(showlegend=True, title='周波数応答関数（位相）（スイープ範囲）', xaxis_title='周波数 [Hz]', yaxis_title='位相 [deg]')
fig.update_xaxes(range=[0, 10])  # X軸を0～10Hzに制限
fig.show()
