# %%
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.execute()
# Out:
# Executing motion flow...

# %%
flow.load_config()
flow.config.get_config()
# Out:
# {'version': '0.0.1',
#  'motor': [{'type': 'linear', 'max_force': 5.0}],
#  'encoder': [{'type1': 'abosolute', 'type2': 'linear', 'resolution_m': 1e-09}],
#  'physical_object': [{'mass': 1.0}]}

# %%
flow.load_motion_profile()
flow.motion_profile.get_profile()
# Out:
# {'version': '0.0.1',
#  'motion_profile': [{'type': 'trapezoid',
#    'max_velocity_m_s': 0.01,
#    'acceleration_m_s2': 0.005,
#    'length_m': 0.1}]}

# %%
print(f"{flow.mprof.version=}")
print(f"{flow.mprof.type=}")
print(f"{flow.mprof.V=}")
print(f"{flow.mprof.A=}")
print(f"{flow.mprof.L=}")
# Out:
# flow.motion_profile.version='0.0.1'
# flow.motion_profile.type='trapezoid'
# flow.motion_profile.V=0.01
# flow.motion_profile.A=0.005
# flow.motion_profile.L=0.1
