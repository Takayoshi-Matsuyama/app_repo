# %%
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.execute()
# Out:
# Executing motion flow...

# %%
flow.load_config()
flow.config
# Out:
# Loading configuration...
# [{'version': '0.0.1',
#   'motor': [{'type': 'linear', 'max_force': 5.0}],
#   'encoder': [{'type1': 'abosolute',
#     'type2': 'linear',
#     'resolution_m': 1e-09}],
#   'physical_object': [{'mass': 1.0}]}]

# %%
flow.load_motion_profile()
flow.motion_profile
# Out:
# [{'version': '0.0.1',
#   'motion_profile': [{'type': 'trapezoidal',
#     'max_velocity_m_s': 0.01,
#     'acceleration_m_s2': 0.005,
#     'length_m': 0.1}]}]
