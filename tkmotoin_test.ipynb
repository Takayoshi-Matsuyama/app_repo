# %%
import tkmotion as tkm
flow = tkm.MotionFlow()
flow.execute()
# Out:
# Executing motion flow...

# %%
flow.load_config()
flow.config
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 flow.load_config()
#       2 flow.config
#
# AttributeError: 'MotionFlow' object has no attribute 'load_config'
